# %%
print("12")
# Out:
# 12

# %%
print(12)
# Out:
# 12

# %%
12-2
# Out:
# 10

# %%
x = 2

print(x)
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
c = "hello world"
print(c)
type(c)
# Out:
# hello world
# str

# %%
c = "hello"

print(c)
# Out:
# hello

# %%
a = 12
print(a)
# Out:
# 12

# %%
w = a+2
print(w)
# Out:
# 14

# %%
a = "5"
b = a+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_16878/1375451330.py in <module>
#       1 a = "5"
# ----> 2 b = a+2
#
# TypeError: can only concatenate str (not "int") to str

# %%
3 * 12
# Out:
# 36

# %%
arsalan_ahmed_hameed = "brave"
arsalan_ahmed_hameed
# Out:
# 'brave'

# %%
10%6
# Out:
# 4

# %%
age = 12
print(age)

age +=1
print(age)
# Out:
# 12
# 13

# %%
++age

print(age)
# Out:
# 13

# %%
age = 12

age *= 3
print(age)
# Out:
# 36

# %%
age**2
# Out:
# 1296

# %%
36 * 36
# Out:
# 1296

# %% [markdown]
# ###BODMAS RULE

# %% [markdown]
# ##BODMAS RULE

# %% [markdown]
# BODMAS RULE
# B= BRACKET
# O= ORDER
# D= DIVIDE
# M= MULTIPLY
# A= ADDITION
# S= SUBTRACTION

# %%
(1 + 4) * 2 + 4 / 2
# Out:
# 12.0

# %%
age = int(input())
if age >= 12:
    print("you are allowed")
else:
    print("you are not")
# Out:
# 11
# you are not

# %%
age = int(input())
if age >= 12 or age < 18:
    print("you are allowed")
elif age>=18:
    print("you are not a kid")
else:
    print("not allowed")
# Out:
# 19
# you are allowed

# %%
'''age = int(input())
if age >= 12:
    if age <=18:
        print("you are not 18+")
    if age >=18:
        print("you are 18+")
'''
else:
    print("you are under aged")
# Out:
# 19
# you are 18+
